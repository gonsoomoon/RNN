# %% [markdown]
# <h1>Rossman sales prediction model and inference with the same store id and differnt one

# %% [markdown]
# <li>Make a train and test data set

# %%
import numpy as np
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')

# %% [markdown]
# <li> Open input files and save them as pickle files

# %%
# Input file: train_data = "./data/train.csv" 
#             store_data = "./data/store.csv"
#             store_states = './data/store_states.csv'
# Output file
#             TRAIN_OUTPUT = "./data/train_data.pickle"
#             STORE_DATA_OUTPUT = "./data/store_data.pickle"

from extract_csv_files import InputFile

# %%
InputFile()
# Out:
# train data:
#  [{'Store': '1115', 'DayOfWeek': '2', 'Date': '2013-01-01', 'Sales': '0', 'Customers': '0', 'Open': '0', 'Promo': '0', 'StateHoliday': 'a', 'SchoolHoliday': '1'}, {'Store': '1114', 'DayOfWeek': '2', 'Date': '2013-01-01', 'Sales': '0', 'Customers': '0', 'Open': '0', 'Promo': '0', 'StateHoliday': 'a', 'SchoolHoliday': '1'}, {'Store': '1113', 'DayOfWeek': '2', 'Date': '2013-01-01', 'Sales': '0', 'Customers': '0', 'Open': '0', 'Promo': '0', 'StateHoliday': 'a', 'SchoolHoliday': '1'}]:
# store data:
# ...

# %% [markdown]
# <li>With train_data.pickle and store_data.pickle as an input, makes les.pickle and feature_train_data.pickle

# %%
# Input:  
#         TRAIN_DATA_OUTPUT = './data/train_data.pickle'
#         STORE_DATA_OUTPUT = './data/store_data.pickle'
# Output:
#         LABEL_ENCODINGS = './data/les.pickle'
#         FEATURE_TRAIN_DATA = './data/feature_train_data.pickle'

from prepare_features import SupervisedFeature

# %%
SupervisedFeature()
# Out:
# Number of train data points:  844338

# %% [markdown]
# <li> A embedding model

# %%
from models import Model_Util, Model, NN_with_EntityEmbedding, NN_with_EntityEmbedding_Loading
# Out:
# Using TensorFlow backend.

# %% [markdown]
# <li> Learning a model

# %%
from train_test_model import TRAIN_DRIVER

# %%
TRAIN_DRIVER()
# Out:
# Number of samples used for training: 675470
# Fitting NN_with_EntityEmbedding...
# Train on 675470 samples, validate on 168868 samples
# Epoch 1/1
#  - ETA: 6s - loss: 0.0105
# Saved model to disk
# Result on validation data:  0.1227646318366245
# Evaluate combined models...
# Training error...
# guessed_sales: [[7911.4595 4489.9824 8066.391  ... 7691.1123 8419.336  7786.1523]]
# 0.09168160279847933
# Validation error...
# guessed_sales: [[4225.582  8317.82   4869.286  ... 7811.671  5609.492  4950.3877]]
# 0.1227646318366245

# %% [markdown]
# <li>Inference of comparing the same store id and different store id

# %%
from inference import Inference

# %%
inference = Inference()
inference.inference_val_data()
inference.inference_no_storeid()
# Out:
# Number of samples used for training: 200000
# Evaluate combined models...
# Training error...
# guessed_sales: [[7911.4595 4489.9824 8066.391  ... 3344.6013 9628.14   4262.0024]]
# 0.09644983731422521
# Validation error...
# guessed_sales: [[7077.2466 6076.296  3133.0754 ... 7811.671  5609.492  4950.3877]]
# 0.1190780317379576
# Test error...
# ground_true: 5263 , guessed_sales: [[4950.3877]], diff: [[312.6123]]
# 0.05939812
# With no store id, Test error...
# ground_true: 5263 , guessed_sales: [[6309.9]], diff: [[-1046.8999]]
# 0.19891694
